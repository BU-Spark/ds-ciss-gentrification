# %%
# Libaries for parsing data
from lxml import etree
from bs4 import BeautifulSoup
import pandas as pd
import os

# Libraries from nltk
import nltk
import string
from nltk import collocations 
from nltk.text import Text
from nltk.tokenize import WhitespaceTokenizer
from nltk.corpus import stopwords

# Library for plotting
import matplotlib.pyplot as plt

# %%
# Modify corpus to the dataset path
corpus = './data/Boston_Globe_Source/'
#corpus = './data/Chicago_Tribune_Source/'
#corpus = './data/Los_Angeles_Times_Source/'
#corpus = './data/The_Washington_Post_Source/'
#corpus = './data/New_York_Times_Source/'
#corpus = './data/The_Wall_Street_Journal_Source/'
# Read in files
input_files = os.listdir(corpus)

# %%
# Select the number of articles to sample
sample_size = 100

# Generate a sample of articles
try:
    #sample_input_files = input_files[0:sample_size]
    sample_input_files = input_files

except ValueError:
    sample_input_files = input_files
    
print("Currently sampling", len(sample_input_files), "documents.")
print(input_files)
# Out:
# Currently sampling 1703 documents.
# ['2667058638.xml', '2152088797.xml', '2418789818.xml', '1811958975.xml', '1974509364.xml', '2460562215.xml', '1816413153.xml', '1796411889.xml', '1779826223.xml', '2633558148.xml', '2649820622.xml', '2701235704.xml', '2297159505.xml', '2694615000.xml', '1974668519.xml', '2329344451.xml', '1634393092.xml', '2584432988.xml', '2202084219.xml', '1974672336.xml', '1974660904.xml', '2205451625.xml', '2225977292.xml', '2437865582.xml', '2349191081.xml', '2398550670.xml', '1790227394.xml', '1974491944.xml', '2176522685.xml', '2232147322.xml', '1768397354.xml', '2131719756.xml', '2477131339.xml', '2743864346.xml', '2637120523.xml', '2443061969.xml', '1515458240.xml', '1974438883.xml', '1766897610.xml', '2635873015.xml', '1974576146.xml', '2019729332.xml', '2066445584.xml', '1974588446.xml', '1640598023.xml', '1512815456.xml', '1947356470.xml', '2495540093.xml', '1961490863.xml', '2555715498.xml', '1867205849.xml', '2543873334.xml', '2471114524.xml', '1928144285.xml', '2450799946.xml', '1974442269.xml', '2482052637.xml', '1974409674.xml', '1974539007.xml', '2570509221.xml', '2722755357.xml', '1974617480.xml', '1974589383.xml', '1974590899.xml', '1968839242.xml', '1974649120.xml', '1877704472.xml', '1722347935.xml', '1878703221.xml', '1674904223.xml', '1993942135.xml', '2006201256.xml', '1692675265.xml', '2245723510.xml', '2008954319.xml', '2082131653.xml', '2119118523.xml', '2089227148.xml', '1974612207.xml', '1280627967.xml', '2358648478.xml', '2717577020.xml', '2181926787.xml', '2432505704.xml', '2560987482.xml', '2440976458.xml', '1525569145.xml', '1974700037.xml', '2667066816.xml', '1974569188.xml', '2637501351.xml', '2422520093.xml', '1990002523.xml', '1974680436.xml', '2730915864.xml', '2245755007.xml', '2311166095.xml', '1320050251.xml', '2334579167.xml', '1531853044.xml', '2570513727.xml', '2628520129.xml', '1786389020.xml', '1838663439.xml', '1974532376.xml', '1974437244.xml', '2226934071.xml', '2189250036.xml', '1967053451.xml', '1400954718.xml', '2190228617.xml', '1552194130.xml', '1494647835.xml', '1789902217.xml', '2466559097.xml', '2724674129.xml', '2601533008.xml', '1324510273.xml', '1790200689.xml', '1974621699.xml', '2545306083.xml', '2258924543.xml', '1974565197.xml', '1927586889.xml', '2465662561.xml', '1081392361.xml', '2623861759.xml', '1974679977.xml', '2312297916.xml', '1974558977.xml', '2311166062.xml', '2082113193.xml', '1990004621.xml', '2701372742.xml', '2071681480.xml', '1843013213.xml', '1825338848.xml', '2503562071.xml', '2459436462.xml', '2513469023.xml', '1974491746.xml', '2391256526.xml', '1974569889.xml', '2722755402.xml', '2621773877.xml', '1974231135.xml', '2082124270.xml', '1449746314.xml', '2626109524.xml', '2361440391.xml', '2687166736.xml', '2177682546.xml', '1713829465.xml', '1974423596.xml', '2509470983.xml', '2667046568.xml', '2418776640.xml', '2210822119.xml', '2693926945.xml', '1912336194.xml', '1672344250.xml', '1720380806.xml', '2436229603.xml', '1974610045.xml', '2300341678.xml', '1616419118.xml', '2431186244.xml', '2722755359.xml', '2138625932.xml', '1903027094.xml', '2103817758.xml', '1990003554.xml', '2575595453.xml', '2414524689.xml', '1902820042.xml', '1974617439.xml', '1976294971.xml', '2013559567.xml', '1976177400.xml', '1771063821.xml', '2656827802.xml', '1989963111.xml', '2140789580.xml', '2584429249.xml', '2373983201.xml', '2528424117.xml', '2661973441.xml', '1976303591.xml', '2754892407.xml', '1974704059.xml', '2676628967.xml', '2580774205.xml', '928853935.xml', '1498264204.xml', '2709825253.xml', '1974574843.xml', '1974508596.xml', '2637805061.xml', '1974672619.xml', '2651001845.xml', '1974611207.xml', '1974622329.xml', '1974502776.xml', '1974695853.xml', '2450799136.xml', '2436229063.xml', '2210733173.xml', '2002035515.xml', '2181932637.xml', '1976309950.xml', '2170718122.xml', '2283136109.xml', '2735728964.xml', '2373782238.xml', '1977621681.xml', '2458332313.xml', '2060814496.xml', '2613703770.xml', '2190152507.xml', '2375260833.xml', '2476847310.xml', '2676693118.xml', '197 ...

# %%
# Function to strip html tags from text portion
def strip_html_tags(text):
    stripped = BeautifulSoup(text).get_text().replace('\n', ' ').replace('\\', '').strip()
    return stripped

# %%
# Retrieve metadata from XML document
def getxmlcontent(corpus, file, strip_html=True):
    try:
        tree = etree.parse(corpus + file)
        root = tree.getroot()

        if root.find('.//GOID') is not None:
            goid = root.find('.//GOID').text
        else:
            goid = None

        if root.find('.//Title') is not None:
            title = root.find('.//Title').text
        else:
            title = None

        if root.find('.//NumericDate') is not None:
            date = root.find('.//NumericDate').text
        else:
            date = None
            
        if root.find('.//PublisherName') is not None:
            publisher = root.find('.//PublisherName').text
        else:
            publisher = None

        if root.find('.//FullText') is not None:
            text = root.find('.//FullText').text

        elif root.find('.//HiddenText') is not None:
            text = root.find('.//HiddenText').text

        elif root.find('.//Text') is not None:
            text = root.find('.//Text').text

        else:
            text = None

        # Strip html from text portion
        if text is not None and strip_html == True:
            text = strip_html_tags(text)
    
    except Exception as e:
        print(f"Error while parsing file {file}: {e}")
    
    return goid, title, date, publisher, text

# %%
# Create lists to store GOIDs, texts, and dates
goid_list = []
text_list = []
date_list = []

for file in sample_input_files:
    
    goid, title, date, publisher, text = getxmlcontent(corpus, file, strip_html=True)
    
    if text is not None:
        goid_list.append(goid)
        text_list.append(text)
        date_list.append(date)

# %%
# Create a dataframe, setting each of the columns to one of the lists we made in the cell above
df = pd.DataFrame({'GOID': goid_list, 'Text': text_list, 'Date': date_list})

# %%
print(len(df['Text'][0]))
# Out:
# 8330

# %%
nltk.data.path.append('../Resources/nltk_data/')

# %%
import re

# %%
# Function to find contextual neighborhood
def keyword_neighbor_counter(keyword, text, window_size, freq):

    tknr = WhitespaceTokenizer() 
#     stop_words = set(stopwords.words('english'))
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
#     word_tokens = word_tokenize(text)
#     filtered_sentence = [w for w in word_tokens if not w in stop_words]
    #with no lower case conversion
#     filtered_sentence = []

#     for w in word_tokens:
#         if w not in stop_words:
#             filtered_sentence.append(w)
            
#     print(filtered_sentence)
    word = r"\W*([\w]+)"
    grps = re.search(r'{}\W*{}{}'.format(word*window_size,keyword,word*window_size), text)
    if grps is None:
        return None
    else:
        groups = grps.groups()
        return groups[:window_size],groups[window_size:]

# %%
# Define keyword
keyword = 'gentrification of'

# %%
# Define window size
window_size = 3

# Define frequency
frequency = 5

# %%
df["left_context"] = ""
df["right_context"] = ""
df["Sentences"] = ""
for idx in df.index:
    text = str(df["Text"][idx])
    if keyword in text:
#         print("has gentrification of ", df["GOID"][idx])
        
#         print(text)
        
        # Use function to gather the contextual neighborhood
        left, right = keyword_neighbor_counter(keyword, text, window_size=window_size, freq=frequency)
        df["left_context"][idx]=left
        df["right_context"][idx]=right
        df["Sentences"][idx] = re.findall(r"([^.]*?gentrification of[^.]*\.)",text)
        print(df["left_context"][idx])
# Out:
# ('coal', 'mine', 'the')
# ('lead', 'to', 'further')
# ('been', 'called', 'the')
# ('tributary', 'brewing', 'the')
# ('affordable', 'housing', 'the')
# ('fries', 'is', 'the')
# ('battling', 'the', 'relentless')
# ('lynn', 'because', 'the')
# ('he', 'said', 'the')
# ('step', 'in', 'the')
# ('battling', 'the', 'gentrification')
# ('the', 'table', 'the')
# ('expressing', 'concern', 'about')
# ('thus', 'began', 'the')
# ('dealing', 'with', 'the')
# ('aligned', 'with', 'the')
# ('the', 'table', 'the')
# ('battling', 'the', 'relentless')
# ('fries', 'is', 'the')
# ('housing', 'the', 'gentrification')
# ('more', 'specifically', 'the')
# ('80s', 'the', 'hellbent')
# ('town', 'noting', 'the')
# ('increase', 'we', 'see')
# ('units', 'could', 'hasten')
# ('further', 'accelerating', 'the')
# ('to', 'increased', 'rents')
# ('accelerating', 'the', 'gentrification')
# ('town', 'noting', 'the')
# ('participating', 'in', 'the')
# ('further', 'accelerating', 'the')
# ('lynn', 'because', 'the')
# ('for', 'the', 'gentrification')
# ('battling', 'the', 'relentless')
# ('the', 'most', 'rapid')
# ('thus', 'began', 'the')
# ('the', 'relentless', 'relentless')
# ('symbol', 'of', 'the')
# ('symbol', 'of', 'the')
# ('the', 'most', 'rapid')
# ('been', 'called', 'the')
# ('penalty', 'and', 'fought')
# ('jarbeau', 'said', 'for')
# ('the', 'most', 'rapid')
# ('fries', 'is', 'the')
# ('displacement', 'and', 'the')
# ('pointing', 'to', 'the')
# ('to', 'the', 'ongoing')
# ('tributary', 'brewing', 'the')
# ('displacement', 'and', 'the')
# ('with', 'continued', 'continued')
# ('aligned', 'with', 'the')
# ('break', 'neighborhoods', 'because')
# ('call', 'the', 'gentrification')
# ('the', 'most', 'rapid')
# ('he', 'laments', 'that')
# ('said', 'the', 'gentrification')
# ('pointing', 'to', 'the')
# ('he', 'said', 'the')
# ('result', 'of', 'white')
# ('at', 'mum', 's')
# ('jarbeau', 'said', 'for')
# ('result', 'of', 'white')
# ('increase', 'we', 'see')
# ('pointing', 'to', 'the')
# ('courtesy', 'below', 'the')
# ('aligned', 'with', 'the')
# ('the', 'table', 'the')
# ('with', 'the', 'gentrification')
# ('coal', 'mine', 'the')
# ('expressing', 'concern', 'about')
# ('to', 'the', 'ongoing')
# ('doubt', 'that', 'the')
# ('deal', 'with', 'the')
# ('increased', 'rents', 'gentrification')
# ('affordable', 'housing', 'the')
# ('deal', 'with', 'the')
# ('lead', 'to', 'further')
# ('desire', 'for', 'the')
# ('units', 'could', 'hasten')
# ('than', 'decreased', 'the')
# ('step', 'in', 'the')
# ('look', 'at', 'the')
# ('thus', 'began', 'the')
# ('eyes', 'at', 'mums')
# ('jarbeau', 'said', 'for')
# ('to', 'further', 'gentrification')
# ('participating', 'in', 'the')
# ('an', 'irish', 'lass')
# ('the', 'table', 'the')
# ('immigrants', 'and', 'the')
# ('family', 'battling', 'the')
# ('expressing', 'concern', 'about')
# ('look', 'at', 'the')
# ('call', 'the', 'gentrification')
# ('80s', 'the', 'hellbent')
# ('deal', 'with', 'continued')
# ('noting', 'the', 'gentrification')
# ('neighborhoods', 'because', 'gentrification')
# ('could', 'hasten', 'gentrification')
# ('than', 'decreased', 'the')
# ('80s', 'the', 'hellbent')
# ('been', 'called', 'the')
# ('the', 'most', 'rapid')
# ('some', 'call', 'the')
# ('courtesy', 'below', 'the')
# ('to', 'increased', 'rents')
# ('he', 'laments', 'that')
# ('of', 'white', 'gentrification')
# ('displacement', 'and', 'the')
# ('look', 'at', 'the')
# ('accidental', 'courtesy', 'the')

# %%
#print("left context : ", df["left_context"])
#print("right context : ", df["right_context"])
print("sentences: ", df["Sentences"])
# Out:
# sentences:  0
# 1
# 2
# 3       [ The gentrification of Mystic is marked by th...
# 4
#                               ...
# 1698
# 1699
# 1700
# 1701
# 1702
# Name: Sentences, Length: 1703, dtype: object

# %%
df = df[df["left_context"] != ""]

# %%
print(len(df["Sentences"]))
# Out:
# 112

# %%
lefts = ' '.join(str(' '.join(x)) for x in df["left_context"])
print(lefts)
rights = ' '.join(str(' '.join(x)) for x in df["right_context"])
print(rights)
# Out:
# coal mine the lead to further been called the tributary brewing the affordable housing the fries is the battling the relentless lynn because the he said the step in the battling the gentrification the table the expressing concern about thus began the dealing with the aligned with the the table the battling the relentless fries is the housing the gentrification more specifically the 80s the hellbent town noting the increase we see units could hasten further accelerating the to increased rents accelerating the gentrification town noting the participating in the further accelerating the lynn because the for the gentrification battling the relentless the most rapid thus began the the relentless relentless symbol of the symbol of the the most rapid been called the penalty and fought jarbeau said for the most rapid fries is the displacement and the pointing to the to the ongoing tributary brewing the displacement and the with continued continued aligned with the break neighborhoods because call the gentrification the most rapid he laments that said the gentrification pointing to the he said the result of white at mum s jarbeau said for result of white increase we see pointing to the courtesy below the aligned with the the table the with the gentrification coal mine the expressing concern about to the ongoing doubt that the deal with the increased rents gentrification affordable housing the deal with the lead to further desire for the units could hasten than decreased the step in the look at the thus began the eyes at mums jarbeau said for to further gentrification participating in the an irish lass the table the immigrants and the family battling the expressing concern about look at the call the gentrification 80s the hellbent deal with continued noting the gentrification neighborhoods because gentrification could hasten gentrification than decreased the 80s the hellbent been called the the most rapid some call the courtesy below the to increased rents he laments that of white gentrification displacement and the look at the accidental courtesy the
# mystic is marked a neighborhood once roxbury roxbury and the foreside has neighborhoods and the the churro wrote their neighborhood follows the south boston the maine coastline a neighborhood that the neighborhood it los angeles was the somerville neighborhood cable while your the neighborhood 495 new york for los angeles was their neighborhood follows the churro wrote neighborhoods and the provincetown in the new york and some city neighborhoods neighborhoods that used a neighborhood where chinatown and the neighborhoods and a chinatown and the some city neighborhoods neighborhoods are not chinatown and the the south boston the last standing their neighborhood will any city in cable while your their neighborhood neighborhood the neighborhood an the neighborhood an any city in roxbury and that the urban neighborhoods the coast one any city in the churro wrote lower roxbury on the area at ashmont the sixalarm the foreside has lower roxbury on the city center new york for ten comes hitched his neighborhood comes any city in ten ne residents the maine coastline the area at the maine coastline neighborhoods that were brixton calls her the coast one neighborhoods that were neighborhoods that used the area at marthas vineyard is new york for los angeles was the neighborhood 495 mystic is marked the somerville neighborhoodthe ashmont the sixalarm a large part their neighborhood the neighborhoods and a neighborhoods and the their neighborhood the a neighborhood once the last standing a neighborhood where san francisco looking a neighborhood that detroit in a cable while your brixton calls her the coast the a neighborhood once neighborhoods are not nyc is weighs los angeles was black neighborhoods neighborhoods the neighborhood it the somerville neighborhoodthe detroit in a his neighborhood comes new york and the city center some city neighborhoods ten comes hitched a neighborhood where san francisco looking new york and roxbury and that any city in his neighborhood comes marthas vineyard is neighborhoods and a ten displaces the neighborhoods that were lower roxbury on detroit in a marthas vineyard is

# %%
from collections import Counter
lfreq = Counter(lefts.split()).most_common()
print("LEFTS: ",lfreq)
print("\n")
rfreq = Counter(rights.split()).most_common()
print("RIGHTS: ",rfreq)
# Out:
# LEFTS:  [('the', 86), ('gentrification', 14), ('to', 10), ('with', 9), ('said', 6), ('further', 5), ('battling', 5), ('relentless', 5), ('for', 5), ('most', 5), ('rapid', 5), ('of', 5), ('and', 5), ('at', 5), ('because', 4), ('he', 4), ('in', 4), ('table', 4), ('been', 3), ('called', 3), ('housing', 3), ('fries', 3), ('is', 3), ('expressing', 3), ('concern', 3), ('about', 3), ('thus', 3), ('began', 3), ('aligned', 3), ('80s', 3), ('hellbent', 3), ('noting', 3), ('could', 3), ('hasten', 3), ('accelerating', 3), ('increased', 3), ('rents', 3), ('jarbeau', 3), ('displacement', 3), ('pointing', 3), ('continued', 3), ('call', 3), ('that', 3), ('white', 3), ('courtesy', 3), ('deal', 3), ('look', 3), ('coal', 2), ('mine', 2), ('lead', 2), ('tributary', 2), ('brewing', 2), ('affordable', 2), ('lynn', 2), ('step', 2), ('town', 2), ('increase', 2), ('we', 2), ('see', 2), ('units', 2), ('participating', 2), ('symbol', 2), ('ongoing', 2), ('neighborhoods', 2), ('laments', 2), ('result', 2), ('below', 2), ('than', 2), ('decreased', 2), ('dealing', 1), ('more', 1), ('specifically', 1), ('penalty', 1), ('fought', 1), ('break', 1), ('mum', 1), ('s', 1), ('doubt', 1), ('desire', 1), ('eyes', 1), ('mums', 1), ('an', 1), ('irish', 1), ('lass', 1), ('immigrants', 1), ('family', 1), ('some', 1), ('accidental', 1)]
#
#
# RIGHTS:  [('the', 43), ('neighborhood', 25), ('neighborhoods', 19), ('a', 15), ('and', 15), ('city', 10), ('that', 9), ('in', 9), ('roxbury', 7), ('is', 6), ('their', 6), ('new', 6), ('york', 6), ('any', 5), ('comes', 5), ('los', 4), ('angeles', 4), ('was', 4), ('ten', 4), ('once', 3), ('churro', 3), ('wrote', 3), ('maine', 3), ('coastline', 3), ('somerville', 3), ('cable', 3), ('while', 3), ('your', 3), ('for', 3), ('some', 3), ('where', 3), ('chinatown', 3), ('coast', 3), ('lower', 3), ('on', 3), ('area', 3), ('at', 3), ('his', 3), ('were', 3), ('marthas', 3), ('vineyard', 3), ('detroit', 3), ('mystic', 2), ('marked', 2), ('foreside', 2), ('has', 2), ('follows', 2), ('south', 2), ('boston', 2), ('it', 2), ('495', 2), ('used', 2), ('are', 2), ('not', 2), ('last', 2), ('standing', 2), ('an', 2), ('one', 2), ('ashmont', 2), ('sixalarm', 2), ('center', 2), ('hitched', 2), ('brixton', 2), ('calls', 2), ('her', 2), ('neighborhoodthe', 2), ('san', 2), ('francisco', 2), ('looking', 2), ('provincetown', 1), ('will', 1), ('urban', 1), ('ne', 1), ('residents', 1), ('large', 1), ('part', 1), ('nyc', 1), ('weighs', 1), ('black', 1), ('displaces', 1)]

# %% [markdown]
# ### Result : A Dataframe with GO_ID, Text, Date, Left, Right context (3 words) and the surrounding sentence

# %%
df.head(10)
# Out:
#            GOID                                               Text  \
# 3    1811958975  MYSTIC -- This one-time shipbuilding center ha...
# 28   2176522685  CAMBRIDGE — For almost 40 years, Marcelle Harr...
# 47   2495540093  ANALYSIS A blow to America, felt across the po...
# 62   1974589383  Foreside merchants craft their own allure ► KI...
# 73   2245723510  At the national level, top-tier Democratic can...
# 75   2082131653  What are Dunkin’s new treats like? We decided ...
# 79   1280627967  Jon Niedzwiecki has watched enough reality TV ...
# 99   1531853044  Judging from photos taken in recent days on th...
# 120  2545306083  FALMOUTH, Maine — One bright, brisk morning la...
# 125  1081392361  On Thursday, the Boston licensing board approv...
#
#            Date                 left_context                   right_context  \
# 3    2016-08-17            (coal, mine, the)            (mystic, is, marked)
# 28   2019-02-06          (lead, to, further)         (a, neighborhood, once)
# 47   2021-01-08          (been, called, the)         (roxbury, roxbury, and)
# 62   2015-03-08    (tributary, brewing, the)            (the, foreside, has)
# 73   2019-06-16   (affordable, housing, the)       (neighborhoods, and, the)
# 75   2018-04-11             (fries, is, the)            (the, churro, wrote)
# 79   2013-01-26  (battling, the, relentless)  (their, neighborhood, follows)
# 99   2014-06-04         (lynn, because, the)            (the, south, boston)
# 120  2021-06-27              (he, said, the)         (the, maine, coastline)
# 125  2012-10-01              (step, in, the)         (a, neighborhood, that)
#
#                                              Sentences
# 3    [ The gentrification of Mystic is marked by th...
# 28   [ A lawyer for Harrison's relatives said they ...
# 47   [ As a councilor, Janey has faced criticism of...
# 62   [ The gentrification of the Foreside has ample...
# 73   [ Affordable housing, the gentrification of ne...
# 75   [ “Dunkin’ Donuts ‘inventing’ donut fries is t...
# 79   [ The show, which the network has said is focu...
# 99   [ In the scene, which was shot in Lynn because...
# 120  [ “The gentrification of the Maine coastline i...
# 125  [ For some, this will be seen as a symbolic ev...

# %%
df.to_csv("Boston-Globe.csv")

# %%
for i in df["Sentences"]:
    print("Sentence : ", i)
# Out:
# Sentence :  [' The gentrification of Mystic is marked by the eateries Red 36 (red36ct.']
# Sentence :  [" A lawyer for Harrison's relatives said they are likely to sell the property once they seize control, an outcome that could lead to further gentrification of a neighborhood once known for its rich community of immigrant, working-class families."]
# Sentence :  [' As a councilor, Janey has faced criticism of what has been called the gentrification of Roxbury.']
# Sentence :  [' The gentrification of the Foreside has ample room for ethnicity too: One of the area’s longer-running restaurants, Tulsi, offers award-winning Indian food from chef Rajesh Mandekar, while the Kittery Dance Hall, home to an arts organization offering classes and community projects, books several several shows each month featuring a global mix of performers.']
# Sentence :  [' Affordable housing, the gentrification of neighborhoods, and the displacement of residents remain citywide concerns, even as Boston experiences its greatest building boom.']
# Sentence :  [' “Dunkin’ Donuts ‘inventing’ donut fries is the gentrification of the churro,” wrote one Twitter user.']
# Sentence :  [' The show, which the network has said is focused on a South Boston family battling the "relentless gentrification of their neighborhood," follows Niedzwiecki\'s family, living in traditional Southie fashion all together in a triple-decker.']
# Sentence :  [' In the scene, which was shot in Lynn because the gentrification of the South Boston waterfront has rendered the place virtually unrecognizable, Johnny Depp, who plays Bulger, is seen with a rifle as he stalks past the bodies of Halloran and Donahue.']
# Sentence :  [' “The gentrification of the Maine coastline is really pushing working waterfront families out.']
# Sentence :  [' For some, this will be seen as a symbolic event, another step in the gentrification of a neighborhood that always wore its grittiness with pride.']
# Sentence :  [' And just as soon as the show started rolling, a question emerged: What is this thing? “Southie Rules” had been billed as a serious drama about a local family “battling” the gentrification gentrification of the neighborhood.']
# Sentence :  [' Bush was president, immigration reform was still on the table, the gentrification of Los Angeles was still in low gear.']
# Sentence :  [' “We will not be able to afford wherever wherever we go — to set up the neon plant and the electricity and get it permitted,” Waller said, expressing concern about gentrification of the Somerville neighborhood.']
# Sentence :  ['  Thus began the gentrification of cable.']
# Sentence :  [" I'm not out to exploit Southie or portray it in a bad light; I want this to be an honest look at a family from Southie dealing with the gentrification of the neighborhood."]
# Sentence :  [' For his next act, he’s thinking thinking about Talking Heads, and how that band’s career arc aligned with the gentrification of New York.']
# Sentence :  [' Bush was president, immigration reform was still on the table, the gentrification of Los Angeles was still in low gear.']
# Sentence :  [' The show, which the network has said is focused on a South Boston family battling the “relentless gentrification of their neighborhood,? follows Niedzwiecki’s family, living in traditional Southie fashion all together in a triple-decker.']
# Sentence :  [' “Dunkin\' Donuts \'inventing\' donut fries is the gentrification of the churro," wrote one Twitter user.']
# Sentence :  [' Affordable housing, the gentrification gentrification of neighborhoods, and the displacement of residents residents remain citywide concerns, concerns, even as Boston experiences experiences its greatest building boom.']
# Sentence :  ['              Ten years before the Supreme Court ruling, and just one year after marriage equality arrived in Massachusetts, Andrew Sullivan famously lamented "The End of Gay Culture" (or, more specifically, the gentrification of Provincetown) in The New Republic, bemoaning the erosion of "distinctive gayness" in the wake of a fresh wave of acceptance.']
# Sentence :  [" The injury may have helped send Pindell into the most fractious debates of her time: Works here address the AIDS crisis of the '80s, the hellbent gentrification of New York and the resulting homelessness epidemic, police brutality, and the Gulf War."]
# Sentence :  [' Boston, he said, is morphing “into a boutique town," noting the gentrification of some city neighborhoods.']
# Sentence :  [' “We see gentrification of neighborhoods that used to be more affordable and suddenly we see million-dollar condos going in," she said, citing developments in traditionally lower-income neighborhoods such as Jamaica Plain and Roxbury.']
# Sentence :  [' Neighbors contend the 200-plus market-rate units could hasten gentrification of a neighborhood where 46 percent of residents are Black and 26 percent are Latino, according to city data.']
# Sentence :  [' The 340-foot tower will isolate two historical Boston neighborhoods from each other and bring more workers seeking to live nearby, further accelerating the gentrification of Chinatown and the Leather District.']
# Sentence :  ['  The study does not address non-restricted units that are being rented at or sold at market-rate prices, which has led in many cases to increased rents, gentrification of neighborhoods, and a citywide affordable housing crisis.']
# Sentence :  [' The 340-foot tower will isolate two historical Boston Boston neighborhoods from each other and bring more workers workers seeking to live nearby, further accelerating the gentrification gentrification of Chinatown and the Leather District.']
# Sentence :  [' Boston, he said, is morphing “into a boutique town," noting the gentrification of some city neighborhoods.']
# Sentence :  ['   In fact, developers participating in the gentrification of neighborhoods are not unaware of the consequences of overbuilding and density.']
# Sentence :  [' The 340-foot tower will isolate two historical Boston neighborhoods from each other and bring more workers seeking to live nearby, further accelerating the gentrification of Chinatown and the Leather District.']
# Sentence :  [' In the scene, which was shot in Lynn because the gentrification of the South Boston waterfront has rendered the place virtually unrecognizable, unrecognizable, Johnny Depp, who plays Bulger, is seen with a rifle as he stalks past the bodies of Halloran and Donahue.']
# Sentence :  [' I don’t know what the president president can say to make me feel better about the terrible situation situation there, but I do know I feel Salisbury Beach, a real place for real people — may it ever be so IN REFERENCE to Thomas Farragher’s desire for the gentrification gentrification of the last standing affordable beach on the North Shore, I can only surmise that he has his, in terms of the beachfront rental that he enjoys enjoys (“Rooting for Salisbury,” Metro, Aug.']
# Sentence :  [' The reality TV show focused on a South Boston family battling the "relentless gentrification of their neighborhood" will premiere on A&E Jan.']
# Sentence :  ['                         The Hub is undergoing the most  rapid gentrification of any city in the country, a new study by the Cleveland Fed finds.']
# Sentence :  [' Thus began the gentrification of cable.']
# Sentence :  [' The reality TV show focused on a South Boston family battling the “relentless “relentless gentrification of their neighborhood” neighborhood” will premiere on A?E Jan.']
# Sentence :  [' But it still provoked furious opposition from neighbors, who see the development as a symbol of the gentrification of the neighborhood.']
# Sentence :  [' But it still provoked provoked furious opposition from neighbors, who see the development as a symbol of the gentrification of the neighborhood.']
# Sentence :  [' The Hub is undergoing the most rapid gentrification of any city in the country, a new study by the Cleveland Fed finds.']
# Sentence :  ['As a councilor, Janey has faced criticism of what has been called the gentrification of Roxbury.']
# Sentence :  [' He marched against the Vietnam War, preached against the death penalty, and fought gentrification of the urban neighborhoods he served.']
# Sentence :  [' “There\'s a significant potential," Jarbeau said, “for gentrification of the coast.']
# Sentence :  [' The Hub is undergoing the most rapid gentrification of any city in the country, a new study by the Cleveland Fed finds.']
# Sentence :  [' “Dunkin\' Donuts \'inventing\' donut fries is the gentrification of the churro," wrote one Twitter user.']
# Sentence :  [" “I believe they're driving displacement and the gentrification of lower Roxbury on purpose."]
# Sentence :  ["“We hear stories of people being pushed out of the neighborhood and I feel like a lot of us really don't know what to do about it,” said Santos, pointing to the gentrification of the area."]
# Sentence :  [' The Treadmark, and before that the Carruth building just across Dot Ave, are monuments to the ongoing gentrification of Ashmont.']
# Sentence :  [" The gentrification of the Foreside has ample room for ethnicity too: One of the area's longer-running restaurants, Tulsi, offers award-winning Indian food from chef Rajesh Mandekar, while the Kittery Dance Hall, home to an arts organization offering classes and community projects, books several shows each month featuring a global mix of performers."]
# Sentence :  [' “I believe believe they’re driving displacement displacement and the gentrification of lower Roxbury on purpose.']
# Sentence :  [' But it still faces challenges and choices: how to deal with continued continued gentrification of the city center, how to develop its waterfront more fully, how to balance density with open space, how a coastal city should confront confront long-term environmental and climate climate risks.']
# Sentence :  [" For his next act, he's thinking about Talking Heads, and how that band's career arc aligned with the gentrification of New York."]
# Sentence :  [' But trains can also break neighborhoods, because gentrification often comes hitched to the back of a rail car.']
# Sentence :  [' Duffy acknowledged that what some call the gentrification gentrification of his neighborhood comes at a price.']
# Sentence :  [' l-SIA?l K NOW Boston is a hot spot for gentrification Highlights from the Boston Reed Estate Now blog The Hub is undergoing the most rapid gentrification of any city in the country, a new study by the Cleveland Fed finds.']
# Sentence :  [' As a veteran of the ge, even as he laments that gentrification often ne residents.']
# Sentence :  [' “The gentrification gentrification of the Maine coastline is really really pushing working waterfront families out.']
# Sentence :  ['“We hear stories of people being pushed out of the neighborhood and I feel like a lot of us really don\'t know what to do about it," said Santos, pointing to the gentrification of the area.']
# Sentence :  [' “The gentrification of the Maine coastline is really pushing working waterfront families out.']
# Sentence :  [' Many gay and lesbian spaces were the result of white gentrification of neighborhoods that were primarily Black and Latinx.']
# Sentence :  [' When Amma “dared suggest she lower her skirt and heels and raise the scoop neck of her top,” Yazz, who rolls her eyes at “Mum’s gentrification of Brixton,” calls her a “feminazi.']
# Sentence :  [' “There\'s a significant potential," Jarbeau said, “for gentrification of the coast.']
# Sentence :  [' Many gay and lesbian spaces were the result of white gentrification of neighborhoods that were primarily Black and Latinx.']
# Sentence :  [' “We see gentrification of neighborhoods that used to be more affordable and suddenly we see million-dollar condos going in,” she said, citing developments in traditionally lower-income lower-income neighborhoods such as Jamaica Plain and Roxbury.']
# Sentence :  [' “We hear stories of people being pushed out of the neighborhood and I feel like a lot of us really don’t know what to do about it,” said Santos, pointing to the gentrification of the area.']
# Sentence :  ['" Below: The gentrification of Martha\'s Vineyard is the focus of Thomas Bena\'s "One Big Home.']
# Sentence :  [" For his next act, he's thinking about Talking Heads, and how that band's career arc aligned with the gentrification of New York."]
# Sentence :  [' Bush was president, immigration reform was still on the table, the gentrification of Los Angeles was still in low gear.']
# Sentence :  [' I’m not out to exploit Southie or portray it in a bad light; I want this to be an honest look at a family from Southie dealing with the gentrification gentrification of the neighborhood.']
# Sentence :  [' The gentrification of Mystic is marked by the eateries Red 36 (red36ct.']
# Sentence :  ['“We will not be able to afford wherever we go — to set up the neon plant and the electricity and get it permitted," Waller said, expressing concern about gentrification of the Somerville neighborhood.']
# Sentence :  [' The Treadmark, and before that the Carruth building just across Dot Ave, are monuments to the ongoing gentrification of Ashmont.']
# Sentence :  [' 9) No doubt that the gentrification of a large part of the community is real and fits with the results.']
# Sentence :  [' A?E announced Wednesday that it has picked up “Southie Rules,” a reality series that will track “one wicked-stubborn wicked-stubborn native South Boston family” as they deal with the gentrification of their neighborhood.']
# Sentence :  [' WALSH in a statement on the review City survey finds 1 in 5 units income-restricted ►AFFORDABLE HOUSING Continued from Page Cl stricted units that are being rented at or sold at market-rate prices, which has led in many cases to increased rents, gentrification gentrification of neighborhoods, and a citywide affordable housing housing crisis.']
# Sentence :  [' Affordable housing, the gentrification of neighborhoods, and the displacement of residents remain citywide concerns, even as Boston experiences its greatest building boom.']
# Sentence :  [' A&E announced Wednesday that it has picked up "Southie Rules," a reality series that will track "one wicked-stubborn native South Boston family" as they deal with the gentrification of their neighborhood.']
# Sentence :  [" A lawyer for Harrison's relatives said they are likely to sell the property once they seize control, an outcome that could lead to further gentrification of a neighborhood once known for its rich community of immigrant, working-class families."]
# Sentence :  ['In reference to Thomas Farragher\'s desire for the gentrification of the last standing affordable beach on the North Shore, I can only surmise that he has his, in terms of the beachfront rental that he enjoys ("Rooting for Salisbury," Metro, Aug.']
# Sentence :  [' Neighbors contend the 200-plus market-rate units could hasten gentrification of a neighborhood where 46 percent of residents are Black and 26 percent are Latino, according to city data.']
# Sentence :  [' Taken together, rent control increased, rather than decreased, the gentrification of San Francisco.']
# Sentence :  [' For some, this will be seen as a symbolic event, another step in the gentrification of a neighborhood that always wore its grittiness with pride.']
# Sentence :  [" “It's a historical look at the gentrification of Detroit in a neighborhood filled with people struggling to keep their community together as real estate developers move in,” Plum says."]
# Sentence :  ['  Thus began the gentrification of cable.']
# Sentence :  [' When Amma “dared suggest she lower her skirt and heels and raise the scoop neck of her top," Yazz, who rolls her eyes at “Mum\'s gentrification of Brixton," calls her a “feminazi.']
# Sentence :  [' “There’s a significant potential,” Jarbeau said, “for gentrification of the coast.']
# Sentence :  [' Lack of a will could cost family its longtime home ►HOUSE Continued from PageAl seize control, an outcome that could lead to further gentrification gentrification of a neighborhood once known for its rich community of immigrant, working-class families.']
# Sentence :  [' In fact, developers participating in the gentrification of neighborhoods are not unaware of the consequences of overbuilding overbuilding and density.']
# Sentence :  [' Class Divide (2015): The (9:15) Brooklyn (2015) (CC): An Irish lass gentrification of NYC is weighs suitors ho PG-13 examined, ho TV-PG NEW Westwori MBO r (6:15) Fantastic Fonr (2015) PG-13 Westworid (CC) ho TV-MA (9:15) 1 Love You, Mm (2009) (CC) MO R Vacation ?2015) (CC moR Wowtwp Masters of Sex: Art and Nancy throw a party.']
# Sentence :  [' Bush was president, immigration reform reform was still on the table, the gentrification of Los Angeles was still in low gear.']
# Sentence :  [' An influx of immigrants and the gentrification of black neighborhoods neighborhoods contributed to the change, the study said, but suburbanization suburbanization by blacks was even more instrumental.']
# Sentence :  ['             And just as soon as the show started rolling, a question emerged: What is this thing?             "Southie Rules" had been billed as a serious drama about a local family "battling" the gentrification of the neighborhood.']
# Sentence :  ['“We will not be able to afford wherever we go — to set up the neon plant and the electricity and get it permitted,” Waller said, expressing concern about gentrification of the Somerville neighborhood.']
# Sentence :  [' “It’s a historical look at the gentrification of Detroit in a neighborhood filled with people struggling struggling to keep their community together as real estate developers move in,” Plum says.']
# Sentence :  [' Duffy acknowledged that what some call the gentrification gentrification of his neighborhood comes at a price.']
# Sentence :  [' The injury may have helped send Pindell into the most fractious fractious debates of her time: Works here address the AIDS crisis of the ’80s, the hellbent gentrification of New York and the resulting homelessness epidemic, epidemic, police brutality, and the Gulf War.']
# Sentence :  [' But it still faces challenges and choices: how to deal with continued gentrification of the city center, how to develop its waterfront more fully, how to balance density with open space, how a coastal city should confront long-term environmental and climate risks.']
# Sentence :  [' Boston, he said, is morphing “into a boutique boutique town,” noting the gentrification gentrification of some city neighborhoods.']
# Sentence :  [' But trains can also break neighborhoods, because gentrification gentrification often comes hitched to the back of a rail car.']
# Sentence :  [' Neighbors contend contend the 200-plus market-rate units could hasten gentrification gentrification of a neighborhood where 46 percent of residents are Black and 26 percent are Latino, Latino, according to city data.']
# Sentence :  [' Taken together, rent control increased, rather than decreased, the gentrification of San Francisco.']
# Sentence :  [" The injury may have helped send Pindell into the most fractious debates of her time: Works here address the AIDS crisis of the '80s, the hellbent gentrification of New York and the resulting homelessness epidemic, police brutality, and the Gulf War."]
# Sentence :  ['As a councilor, Janey has faced criticism of what has been called the gentrification of Roxbury.']
# Sentence :  [' The Hub is undergoing the most rapid gentrification of any city in the country, a new study by the Cleveland Fed finds.']
# Sentence :  ['             Duffy acknowledged that what some call the gentrification of his neighborhood comes at a price.']
# Sentence :  ['? Below: The gentrification of Martha?s Vineyard is the focus of Thomas Bena?s “One Big Home.']
# Sentence :  ['  The study does not address non-restricted units that are being rented at or sold at market-rate prices, which has led in many cases to increased rents, gentrification of neighborhoods, and a citywide affordable housing crisis.']
# Sentence :  [' As a veteran of the South End, he is resigned to change, even as he laments that gentrification often displaces the elderly and low-income residents.']
# Sentence :  [' Many gay and lesbian spaces were the result of white gentrification gentrification of neighborhoods that were primarily primarily Black and Latinx.']
# Sentence :  [" “I believe they're driving displacement and the gentrification of lower Roxbury on purpose."]
# Sentence :  [' “It\'s a historical look at the gentrification of Detroit in a neighborhood filled with people struggling to keep their community together as real estate developers move in," Plum says.']
# Sentence :  ['" The gentrification of Martha\'s Vineyard is the focus of Thomas Bena\'s "One Big Home.']

# %%
df["Date"] = pd.to_datetime(df['Date'])

# %%
df.sort_values(by='Date')
df
# Out:
#             GOID                                               Text  \
# 3     1811958975  MYSTIC -- This one-time shipbuilding center ha...
# 28    2176522685  CAMBRIDGE — For almost 40 years, Marcelle Harr...
# 47    2495540093  ANALYSIS A blow to America, felt across the po...
# 62    1974589383  Foreside merchants craft their own allure ► KI...
# 73    2245723510  At the national level, top-tier Democratic can...
# ...          ...                                                ...
# 1622   928777474  Note: If you go  . . . Fiercely proud of its t...
# 1626  2704031598  LAURIE ESSIG Like gentrification, hetrificatio...
# 1677  2522400410  When Northeastern University filed plans in 20...
# 1684  2667340908  MR. FULLERTON, BETWEEN THE SHEETSPresented by ...
# 1687  1866401203  Sometimes the most acrimonious divisions can b...
#
#            Date                 left_context                right_context  \
# 3    2016-08-17            (coal, mine, the)         (mystic, is, marked)
# 28   2019-02-06          (lead, to, further)      (a, neighborhood, once)
# 47   2021-01-08          (been, called, the)      (roxbury, roxbury, and)
# 62   2015-03-08    (tributary, brewing, the)         (the, foreside, has)
# 73   2019-06-16   (affordable, housing, the)    (neighborhoods, and, the)
# ...         ...                          ...                          ...
# 1622 2012-03-18          (he, laments, that)        (ten, displaces, the)
# 1626 2022-08-08  (of, white, gentrification)  (neighborhoods, that, were)
# 1677 2021-05-06     (displacement, and, the)         (lower, roxbury, on)
# 1684 2022-05-22              (look, at, the)             (detroit, in, a)
# 1687 2017-02-09  (accidental, courtesy, the)      (marthas, vineyard, is)
#
#                                               Sentences
# 3     [ The gentrification of Mystic is marked by th...
# 28    [ A lawyer for Harrison's relatives said they ...
# 47    [ As a councilor, Janey has faced criticism of...
# 62    [ The gentrification of the Foreside has ample...
# 73    [ Affordable housing, the gentrification of ne...
# ...                                                 ...
# 1622  [ As a veteran of the South End, he is resigne...
# 1626  [ Many gay and lesbian spaces were the result ...
# 1677  [ “I believe they're driving displacement and ...
# 1684  [ “It's a historical look at the gentrificatio...
# 1687  [" The gentrification of Martha's Vineyard is ...
#
# [112 rows x 6 columns]

# %%
#Do Entity Recognition and Frequencies of articles with gentrification v/s gentrification of
